# %% [markdown]
# **Dogs VS Cats Classification Problem**

# %% [markdown]
# The Dogs & Cats is a foundational problem for a basic CNN(convolutional neural network) model which involves classifying images as a dog or a cat.The dataset can be used for learning how to develop,evaluate and use convolutional deep learning neural networks for classification of images

# %% [markdown]
# The dataset can be downloaded for free from the Kaggle website.
# Download the dataset by visiting the Dogs vs. Cats Data page and click the “Download All” button.
# Dataset Link : https://www.kaggle.com/c/dogs-vs-cats
# This will download the 850-megabyte file “dogs-vs-cats.zip” to your workstation.
# Unzip the file and you will see train.zip, train1.zip and a .csv file. Unzip the train.zip file, as we will be focusing only on this dataset.
# You will now have a folder called ‘train/‘ that contains 25,000 .jpg files of dogs and cats. The photos are labeled by their filename, with the word “dog” or “cat“.

# %%
from tensorflow.keras.utils import load_img

# %% [markdown]
# **Import Library**

# %%
import os
import cv2
import random
import shutil
import numpy as np 
import pandas as pd 
import seaborn as sns
from keras.models import load_model
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.metrics import confusion_matrix,classification_report
from tensorflow.keras.utils import load_img
from keras.models import Sequential,Model
from keras.layers import Conv2D,Flatten,MaxPooling2D,Dense,GlobalAveragePooling2D,Dropout,BatchNormalization
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau

# %%
import zipfile
zip_ref = zipfile.ZipFile("C:\\Users\\cihat\\Downloads\\dogs-vs-cats.zip","r")
zip_ref.extractall("./train")
zip_ref.close()

# %%
Y = []
path = "C:\\Users\\cihat\\Downloads\\dogs-vs-cats\\train\\"
filenames = os.listdir(path)
for img in os.listdir(path):
    val = img.split(".")[0]
    if val == "dog":
        Y.append('1')
    else:
        Y.append('0')

df = pd.DataFrame({
    'filename' : filenames,
    'category' : Y
})

# %% [markdown]
# Here we see few initial values of our dataframe using df.head()

# %%
df.head()
# Out:
#        filename category
# 0     cat.0.jpg        0
# 1     cat.1.jpg        0
# 2    cat.10.jpg        0
# 3   cat.100.jpg        0
# 4  cat.1000.jpg        0

# %% [markdown]
# Here we see few last values of our dataframe using df.tail()

# %%
df.tail()
# Out:
#            filename category
# 24995  dog.9995.jpg        1
# 24996  dog.9996.jpg        1
# 24997  dog.9997.jpg        1
# 24998  dog.9998.jpg        1
# 24999  dog.9999.jpg        1

# %% [markdown]
# **Plot Random Dataset Image**

# %%
df.sample(5)
# Out:
#            filename category
# 16695  dog.2523.jpg        1
# 15850  dog.1763.jpg        1
# 18588  dog.4227.jpg        1
# 22126  dog.7411.jpg        1
# 12292  cat.9811.jpg        0

# %% [markdown]
# Looking at a few random images in the directory, we can see that the images are coloured and have different shapes and sizes. For example, let’s load and plot some random images of dataset in a single figure. Running below code creates a figure showing some random images from the dataset.We can see that some images are landscape format, some are portrait format, and some are square.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(4, 3, i+1)
    sample = random.choice(filenames)
    filename = path+'/'+sample
    image = imread(filename)
    plt.imshow(image)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Train Test Split**

# %% [markdown]
# Here we are splitting our dataset into two parts. We are separating 20% of our dataset images for validation purpose and keeping rest for training purpose.This is done because we want to validate our trained model on a new set of images and not on the same set of images on which the model is trained. Therefore we want a different set of images apart from our training set upon which we can test our model and see the performance of the trained model on new unseen images.

# %%
train_df,val_df = train_test_split(df,test_size=0.2,random_state = 42)
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %% [markdown]
# **Training Dataframe shape**

# %% [markdown]
# To see our training dataframe shape we are using train_df.shape

# %%
train_df.shape
# Out:
# (20000, 2)

# %% [markdown]
# **Validation Dataframe shape**

# %% [markdown]
# To see our training dataframe shape we are using val_df.shape

# %%
val_df.shape
# Out:
# (5000, 2)

# %% [markdown]
# **Total Count**

# %% [markdown]
# Here by running below code we can see from the plot that images of both dogs and cats are almost equal in both our training and validation dataset. If there is too much difference in number of dogs and cats images then it can cause problem in training of our model

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
val_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Selecting Image Size**

# %% [markdown]
# The photos will have to be reshaped prior to modeling so that all images have the same shape. So we will choose some image height and width constants which will be used later to reshape all images while training process. Here we choose image height and image width as 128,128. That is 25,000 images with 128x128x3 pixels each, or 1,228,800,000 32-bit pixel values.

# %% [markdown]
# **Constants**

# %% [markdown]
# Here we are defining constants to be used in our model code. So as to make our code modular we define all constants in a separate cell.

# %%
batch_size = 32
epochs = 10
train_size = train_df.shape[0]
val_size = val_df.shape[0]
img_hieght = 128
img_width = 128
img_channels = 3

# %% [markdown]
# **Training Generator**

# %% [markdown]
# Image data augmentation is a technique that can be used to artificially expand the size of a training dataset by creating modified versions of images in the dataset.Training deep learning neural network models on more data can result in more skillful models, and the augmentation techniques can create variations of the images that can improve the ability of the fit models to generalize what they have learned to new images. Data augmentation can also act as a regularization technique, adding noise to the training data, and encouraging the model to learn the same features, invariant to their position in the input. Small changes to the input photos of dogs and cats might be useful for this problem, such as small shifts and horizontal flips. These augmentations can be specified as arguments to the ImageDataGenerator used for the training dataset. The augmentations should not be used for the validation dataset, as we wish to evaluate the performance of the model on the unmodified photographs.
# We can use the flow_from_dataframe() function on the data generator and create one iterator for each of the train and validation set. With the help of flow_from_dataframe method you can directly pass the Pandas DataFrame which has the mapping between filenames of the images and their labels..We must specify that the problem is a binary classification problem via the “class_mode” argument, and to load the images with the size of 128×128×3 pixels via the “target_size” argument. We will fix the batch size at 32.

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    horizontal_flip = True,
    zoom_range = 0.2,
    shear_range = 0.1,
    fill_mode = 'reflect',
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "C:\\Users\\cihat\\Downloads\\dogs-vs-cats\\train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# **Working of Image Generator**

# %% [markdown]
# Here we will see working of our training image generator by applying augmentation on a single image selected from our training dataframe.

# %%
example_df = train_df.sample(n=1)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "C:\\Users\\cihat\\Downloads\\dogs-vs-cats\\train",
    x_col='filename',
    y_col='category',
    target_size=(img_hieght,img_width),
    class_mode='raw'
)
# Out:
# Found 1 validated image filenames.

# %% [markdown]
# We can see by running below code 9 different variations of a single image created by data augmentation techniques. We can see how these 9 images differ only by some properties like horizontal flip, zoom etc from each other.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 9):
    plt.subplot(4, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# **Validation Generator**

# %% [markdown]
# We will not apply any data augmentation technique like horizontal flip, zoom etc on validation set because we are not going to use this for training purpose.

# %%
val_datagen = ImageDataGenerator(
    rescale = 1./255,
)

val_generator = val_datagen.flow_from_dataframe(
    val_df,
    "C:\\Users\\cihat\\Downloads\\dogs-vs-cats\\train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# **Building the Model**

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                            patience=2,
                                            factor=0.5,
                                            min_lr = 0.00001,
                                            verbose = 1)
callbacks = [learning_rate_reduction]

# %% [markdown]
# # Model 1

# %%
model = Sequential()

model.add(Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape = (img_hieght,img_width,img_channels)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2Dfilters=(128,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=256,kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 5,112,001
# Trainable params: 5,110,017
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data =  val_generator,
    steps_per_epoch = train_size//batch_size,
    validation_steps = val_size//batch_size,
    callbacks = callbacks
)
# Out:
# C:\Users\cihat\AppData\Local\Temp\ipykernel_13172\3504877836.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/10
# 625/625 [==============================] - 460s 732ms/step - loss: 0.6655 - accuracy: 0.6597 - val_loss: 0.5809 - val_accuracy: 0.7103 - lr: 0.0010
# Epoch 2/10
# 625/625 [==============================] - 371s 593ms/step - loss: 0.5113 - accuracy: 0.7491 - val_loss: 0.4748 - val_accuracy: 0.7778 - lr: 0.0010
# Epoch 3/10
# 625/625 [==============================] - 276s 442ms/step - loss: 0.4514 - accuracy: 0.7873 - val_loss: 0.3838 - val_accuracy: 0.8187 - lr: 0.0010
# Epoch 4/10
# 625/625 [==============================] - 279s 446ms/step - loss: 0.3956 - accuracy: 0.8204 - val_loss: 0.3822 - val_accuracy: 0.8253 - lr: 0.0010
# Epoch 5/10
# 625/625 [==============================] - 290s 464ms/step - loss: 0.3607 - accuracy: 0.8400 - val_loss: 0.9164 - val_accuracy: 0.6496 - lr: 0.0010
# Epoch 6/10
# 625/625 [==============================] - 292s 467ms/step - loss: 0.3322 - accuracy: 0.8536 - val_loss: 0.2769 - val_accuracy: 0.8834 - lr: 0.0010
# Epoch 7/10
# 625/625 [==============================] - 307s 491ms/step - loss: 0.3082 - accuracy: 0.8655 - val_loss: 0.3579 - val_accuracy: 0.8634 - lr: 0.0010
# Epoch 8/10
# 625/625 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8794
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 [==============================] - 311s 497ms/step - loss: 0.2819 - accuracy: 0.8794 - val_loss: 0.4217 - val_accuracy: 0.8185 - lr: 0.0010
# Epoch 9/10
# 625/625 [==============================] - 327s 523ms/step - loss: 0.2640 - accuracy: 0.8862 - val_loss: 0.2368 - val_accuracy: 0.8998 - lr: 5.0000e-04
# Epoch 10/10
# 625/625 [==============================] - 315s 503ms/step - loss: 0.2414 - accuracy: 0.8989 - val_loss: 0.2245 - val_accuracy: 0.9044 - lr: 5.0000e-04

# %%
summary = pd.DataFrame(model.history.history)

# %%
summary[["loss", "val_loss"]].plot();

# %%
summary[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # 2.Model

# %%
model2 = Sequential()

model2.add(Conv2D(filters=16, kernel_size=(3,3),activation='relu',input_shape = (img_hieght,img_width,img_channels)))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Flatten())

model2.add(Dense(128,activation='relu'))

model2.add(Dense(64,activation='relu'))

model2.add(Dense(1,activation='relu'))
model2.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_84 (Conv2D)          (None, 126, 126, 16)      448
#
#  max_pooling2d_76 (MaxPoolin  (None, 63, 63, 16)       0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 61, 61, 32)        4640
#
#  max_pooling2d_77 (MaxPoolin  (None, 30, 30, 32)       0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 28, 28, 64)        18496
#
#  max_pooling2d_78 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 12, 12, 128)       73856
#
#  max_pooling2d_79 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  flatten_19 (Flatten)        (None, 4608)              0
#
#  dense_48 (Dense)            (None, 128)               589952
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  dense_50 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 695,713
# Trainable params: 695,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model2.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data =  val_generator,
    steps_per_epoch = train_size//batch_size,
    validation_steps = val_size//batch_size,
    callbacks = callbacks
)
# Out:
# Epoch 1/10
# C:\Users\cihat\AppData\Local\Temp\ipykernel_20572\178096067.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model2.fit_generator(
# 625/625 [==============================] - 140s 223ms/step - loss: 0.6778 - accuracy: 0.5905 - val_loss: 0.6226 - val_accuracy: 0.6841 - lr: 0.0010
# Epoch 2/10
# 625/625 [==============================] - 139s 222ms/step - loss: 0.6483 - accuracy: 0.6309 - val_loss: 0.6782 - val_accuracy: 0.5950 - lr: 0.0010
# Epoch 3/10
# 625/625 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.6020
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 [==============================] - 138s 221ms/step - loss: 0.6699 - accuracy: 0.6020 - val_loss: 0.6493 - val_accuracy: 0.6508 - lr: 0.0010
# Epoch 4/10
# 625/625 [==============================] - 139s 222ms/step - loss: 0.6213 - accuracy: 0.6709 - val_loss: 0.5776 - val_accuracy: 0.7105 - lr: 5.0000e-04
# Epoch 5/10
# 625/625 [==============================] - 138s 221ms/step - loss: 0.5811 - accuracy: 0.7060 - val_loss: 0.6323 - val_accuracy: 0.7222 - lr: 5.0000e-04
# Epoch 6/10
# 625/625 [==============================] - 138s 222ms/step - loss: 0.6560 - accuracy: 0.6379 - val_loss: 0.6408 - val_accuracy: 0.6394 - lr: 5.0000e-04
# Epoch 7/10
# 625/625 [==============================] - ETA: 0s - loss: 0.6432 - accuracy: 0.6306
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 [==============================] - 138s 221ms/step - loss: 0.6432 - accuracy: 0.6306 - val_loss: 0.6265 - val_accuracy: 0.6530 - lr: 5.0000e-04
# Epoch 8/10
# 625/625 [==============================] - 207s 332ms/step - loss: 0.6313 - accuracy: 0.6464 - val_loss: 0.6046 - val_accuracy: 0.6875 - lr: 2.5000e-04
# Epoch 9/10
# 625/625 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.6436
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 625/625 [==============================] - 216s 346ms/step - loss: 0.6354 - accuracy: 0.6436 - val_loss: 0.6173 - val_accuracy: 0.6689 - lr: 2.5000e-04
# Epoch 10/10
# 625/625 [==============================] - 137s 220ms/step - loss: 0.5996 - accuracy: 0.6830 - val_loss: 0.6141 - val_accuracy: 0.6921 - lr: 1.2500e-04

# %%
summary2 = pd.DataFrame(model2.history.history)

# %%
summary2[["loss", "val_loss"]].plot();

# %%
summary2[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # 3.Model

# %%
model3 = Sequential()

model3.add(Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu',
                  input_shape = (img_hieght,img_width,img_channels)))

model3.add(BatchNormalization())
model3.add(Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Flatten())

model3.add(Dense(128,activation='relu'))

model3.add(Dense(128,activation='relu'))

model3.add(Dense(1,activation='sigmoid'))
model3.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_88 (Conv2D)          (None, 128, 128, 16)      448
#
#  batch_normalization_41 (Bat  (None, 128, 128, 16)     64
#  chNormalization)
#
#  conv2d_89 (Conv2D)          (None, 128, 128, 16)      2320
#
#  batch_normalization_42 (Bat  (None, 128, 128, 16)     64
#  chNormalization)
#
#  max_pooling2d_80 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  conv2d_90 (Conv2D)          (None, 64, 64, 32)        4640
#
#  batch_normalization_43 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  conv2d_91 (Conv2D)          (None, 64, 64, 32)        9248
#
#  batch_normalization_44 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  max_pooling2d_81 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_92 (Conv2D)          (None, 32, 32, 64)        18496
#
#  batch_normalization_45 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  conv2d_93 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_46 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  max_pooling2d_82 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_94 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_47 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  conv2d_95 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_48 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_83 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  flatten_20 (Flatten)        (None, 8192)              0
#
#  dense_51 (Dense)            (None, 128)               1048704
#
#  dense_52 (Dense)            (None, 128)               16512
#
#  dense_53 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 1,360,785
# Trainable params: 1,359,825
# Non-trainable params: 960
# _________________________________________________________________

# %%
model3.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model3.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data =  val_generator,
    steps_per_epoch = train_size//batch_size,
    validation_steps = val_size//batch_size,
    callbacks = callbacks
)
# Out:
# Epoch 1/10
# C:\Users\cihat\AppData\Local\Temp\ipykernel_20572\757128649.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model3.fit_generator(
# 625/625 [==============================] - 529s 844ms/step - loss: 0.6350 - accuracy: 0.6551 - val_loss: 0.6380 - val_accuracy: 0.6695 - lr: 0.0010
# Epoch 2/10
# 625/625 [==============================] - 358s 573ms/step - loss: 0.5244 - accuracy: 0.7401 - val_loss: 0.5924 - val_accuracy: 0.6895 - lr: 0.0010
# Epoch 3/10
# 625/625 [==============================] - 347s 554ms/step - loss: 0.4374 - accuracy: 0.7980 - val_loss: 0.4600 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 4/10
# 625/625 [==============================] - 329s 526ms/step - loss: 0.3705 - accuracy: 0.8372 - val_loss: 0.4240 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 5/10
# 625/625 [==============================] - 327s 523ms/step - loss: 0.3068 - accuracy: 0.8670 - val_loss: 0.2965 - val_accuracy: 0.8666 - lr: 0.0010
# Epoch 6/10
# 625/625 [==============================] - 343s 549ms/step - loss: 0.2576 - accuracy: 0.8911 - val_loss: 0.2458 - val_accuracy: 0.8962 - lr: 0.0010
# Epoch 7/10
# 625/625 [==============================] - 354s 566ms/step - loss: 0.2352 - accuracy: 0.9014 - val_loss: 0.2816 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 8/10
# 625/625 [==============================] - 364s 582ms/step - loss: 0.2106 - accuracy: 0.9126 - val_loss: 0.2434 - val_accuracy: 0.8988 - lr: 0.0010
# Epoch 9/10
# 625/625 [==============================] - 358s 573ms/step - loss: 0.1962 - accuracy: 0.9196 - val_loss: 0.2257 - val_accuracy: 0.9073 - lr: 0.0010
# Epoch 10/10
# 625/625 [==============================] - 383s 613ms/step - loss: 0.1848 - accuracy: 0.9233 - val_loss: 0.1734 - val_accuracy: 0.9289 - lr: 0.0010

# %%
summary3 = pd.DataFrame(model3.history.history)

# %%
summary3[["loss", "val_loss"]].plot();

# %%
summary3[["accuracy", "val_accuracy"]].plot();

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                            patience=2,
                                            factor=0.5,
                                            min_lr = 0.00001,
                                            verbose = 1)
callbacks = [learning_rate_reduction]

# %% [markdown]
# **Fit Model 1**

# %%
summary = pd.DataFrame(model.history.history)

# %% [markdown]
# **Saving the Model**

# %%
model.save("model.h5")

# %% [markdown]
# **Validation Accuracy**

# %%
score = model.evaluate_generator(val_generator)
print(score[1]*100)
# Out:
# C:\Users\cihat\AppData\Local\Temp\ipykernel_20572\4056359736.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(val_generator)
# 91.75999760627747

# %%
score = model2.evaluate_generator(val_generator)
print(score[1]*100)

# %%
score = model3.evaluate_generator(val_generator)
print(score[1]*100)

# %% [markdown]
# **Training Accuracy**

# %% [markdown]
# Here we are going to calculate model's accuracy on training set itself.

# %%
score = model.evaluate_generator(train_generator)
print(score[1]*100)
# Out:
# C:\Users\cihat\AppData\Local\Temp\ipykernel_20572\92563152.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(train_generator)
# 90.81500172615051

# %%
score = model2.evaluate_generator(val_generator)
print(score[1]*100)
# Out:
# C:\Users\cihat\AppData\Local\Temp\ipykernel_20572\743315888.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model2.evaluate_generator(val_generator)
# 69.17999982833862

# %%
score = model3.evaluate_generator(val_generator)
print(score[1]*100)
# Out:
# C:\Users\cihat\AppData\Local\Temp\ipykernel_20572\1523034792.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model3.evaluate_generator(val_generator)
# 92.87999868392944

# %% [markdown]
# **Confusion Matrix**

# %%
conf_datagen = ImageDataGenerator(
    rescale = 1./255,
)

conf_generator = conf_datagen.flow_from_dataframe(
    val_df,
    "C:\\Users\\cihat\\Downloads\\dogs-vs-cats\\train",
    x_col = 'filename',
    y_col = 'category',
    target_size = (img_hieght,img_width),
    batch_size = batch_size,
    shuffle = False,
    class_mode = 'binary'
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %%
y_predict = model.predict_generator(conf_generator)
# Out:
# C:\Users\cihat\AppData\Local\Temp\ipykernel_13172\652915762.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_predict = model.predict_generator(conf_generator)

# %%
y_predict = np.where(y_predict > 0.5, 1, 0)

# %%
p = conf_generator.classes
q = y_predict
p = np.array(p)
q = q.flatten()

# %%
cfm = confusion_matrix(p, q)
print(cfm)
ax= plt.subplot()
sns.heatmap(cfm, annot=True, ax = ax);
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['cats', 'dogs'])
ax.yaxis.set_ticklabels(['cats', 'dogs'])
# Out:
# [[2365  150]
#  [ 329 2156]]
# [Text(0, 0.5, 'cats'), Text(0, 1.5, 'dogs')]

# %%
print(classification_report(p,q))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      2515
#            1       0.93      0.87      0.90      2485
#
#     accuracy                           0.90      5000
#    macro avg       0.91      0.90      0.90      5000
# weighted avg       0.91      0.90      0.90      5000

# %% [markdown]
# **Prediction**

# %% [markdown]
# Here we will see the prediction of our model on a new image with use of model.predict function

# %%
path ="C:\\Users\\cihat\\Downloads\\dogs-vs-cats\\test1\\998.jpg"
img = cv2.imread(path)
plt.imshow(img)
img = cv2.resize(img,(128,128))
img = np.reshape(img,[1,128,128,3])
img = np.divide(img,255)
result = model.predict(img)
if result[0] >= 0.5:
    print("According to our model's prediction below image is of a Dog","\n", "probability = ", result)
else:
    print("According to our model's prediction below image is of a Cat""\n", "probability = ", 1-result,y_predict)
# Out:
# 1/1 [==============================] - 0s 100ms/step
# According to our model's prediction below image is of a Dog
#  probability =  [[0.9935542]] [0 1 0 ... 0 1 0]

# %%
path ="C:\\Users\\cihat\\Downloads\\WhatsApp Image 2023-06-15 at 20.18.10.jpeg"
img = cv2.imread(path)
plt.imshow(img)
img = cv2.resize(img,(128,128))
img = np.reshape(img,[1,128,128,3])
img = np.divide(img,255)
result = model.predict(img)
if result[0] >= 0.5:
    print("According to our model's prediction below image is of a Dog","\n", "probability = ", result)
else:
    print("According to our model's prediction below image is of a Cat""\n", "probability = ", 1-result,y_predict)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# According to our model's prediction below image is of a Dog
#  probability =  [[0.7774287]] [0 1 0 ... 0 1 0]
